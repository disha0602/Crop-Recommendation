# %% [markdown]
# # CROP RECOMMENDATION SYSTEM

# %% [markdown]
# ![](https://images.unsplash.com/photo-1560493676-04071c5f467b?ixid=MXwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHw%3D&ixlib=rb-1.2.1&auto=format&fit=crop&w=968&q=80)

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %%
from pycaret.utils import version
version()
# Out:
# '2.3.10'

# %%
# Importing libraries

from __future__ import print_function
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn import tree
import warnings
warnings.filterwarnings('ignore')

# %%
#PATH = '../input/crop-rv'ecommendation-dataset/Crop_recommendation.cs
import csv
# %cd /content/

# with open('/Crop_recommendation.csv', 'r') as csvfile:
#   reader = csv.reader(csvfile)
#   rows = [row for row in reader]

# print(rows)
df = pd.read_csv('/Crop_recommendation.csv')
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install markupsafe==2.0.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting markupsafe==2.0.1
#   Using cached MarkupSafe-2.0.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (31 kB)
# Installing collected packages: markupsafe
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.1.1
#     Uninstalling MarkupSafe-2.1.1:
#       Successfully uninstalled MarkupSafe-2.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires markupsafe~=2.1.1, but you have markupsafe 2.0.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed markupsafe-2.0.1

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
import jinja2

# %% [markdown]
# **Model performance using normalization**

# %%
from pycaret.classification import *
s=setup(data=df, target='label',
      normalize = True, normalize_method = 'zscore', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# nb                            Naive Bayes    0.9948  0.9999  0.9947  0.9955
# rf               Random Forest Classifier    0.9948  1.0000  0.9948  0.9954
# et                 Extra Trees Classifier    0.9948  1.0000  0.9948  0.9953
# qda       Quadratic Discriminant Analysis    0.9942  0.9999  0.9942  0.9947
# lightgbm  Light Gradient Boosting Machine    0.9896  0.9999  0.9898  0.9911
# dt               Decision Tree Classifier    0.9883  0.9939  0.9883  0.9904
# gbc          Gradient Boosting Classifier    0.9831  0.9999  0.9836  0.9858
# knn                K Neighbors Classifier    0.9714  0.9977  0.9720  0.9762
# lr                    Logistic Regression    0.9708  0.9995  0.9714  0.9735
# lda          Linear Discriminant Analysis    0.9623  0.9996  0.9625  0.9674
# svm                   SVM - Linear Kernel    0.9025  0.0000  0.9030  0.9409
# ridge                    Ridge Classifier    0.7200  0.0000  0.7235  0.7054
# ada                  Ada Boost Classifier    0.2021  0.6995  0.1909  0.1159
# dummy                    Dummy Classifier    0.0513  0.5000  0.0455  0.0026
#
#               F1   Kappa     MCC  TT (Sec)
# nb        0.9947  0.9946  0.9946     0.029
# rf        0.9948  0.9946  0.9946     0.635
# et        0.9948  0.9946  0.9946     0.519
# qda       0.9941  0.9939  0.9939     0.028
# lightgbm  0.9896  0.9891  0.9892     1.315
# dt        0.9883  0.9877  0.9879     0.028
# gbc       0.9830  0.9823  0.9825     7.105
# knn       0.9705  0.9701  0.9704     0.130
# lr        0.9703  0.9694  0.9695     0.469
# lda       0.9619  0.9605  0.9608     0.025
# svm       0.9083  0.8978  0.9004     0.065
# ridge     0.6635  0.7066  0.7135     0.015
# ada       0.1320  0.1597  0.2518     0.359
# dummy     0.0050  0.0000  0.0000     0.021

# %% [markdown]
# **Model performance using feature selection**

# %%
setup(data=df, target='label',
      feature_selection = True, feature_selection_method = 'classic', 
      feature_selection_threshold = 0.2, silent=True)
cm = compare_models()

#feature_selection_method = {classic, boruta}
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# rf               Random Forest Classifier    0.9545  0.9992  0.9541  0.9585
# dt               Decision Tree Classifier    0.9500  0.9738  0.9491  0.9546
# nb                            Naive Bayes    0.9493  0.9992  0.9487  0.9530
# lightgbm  Light Gradient Boosting Machine    0.9493  0.9985  0.9487  0.9539
# et                 Extra Trees Classifier    0.9467  0.9987  0.9460  0.9520
# gbc          Gradient Boosting Classifier    0.9454  0.9986  0.9442  0.9514
# qda       Quadratic Discriminant Analysis    0.9428  0.9991  0.9419  0.9470
# knn                K Neighbors Classifier    0.9103  0.9916  0.9082  0.9185
# lda          Linear Discriminant Analysis    0.8668  0.9960  0.8639  0.8812
# lr                    Logistic Regression    0.8206  0.9907  0.8191  0.8329
# ridge                    Ridge Classifier    0.2722  0.0000  0.2689  0.1988
# svm                   SVM - Linear Kernel    0.2560  0.0000  0.2607  0.2069
# ada                  Ada Boost Classifier    0.1741  0.6909  0.1727  0.0880
# dummy                    Dummy Classifier    0.0500  0.5000  0.0455  0.0025
#
#               F1   Kappa     MCC  TT (Sec)
# rf        0.9538  0.9523  0.9526     0.586
# dt        0.9495  0.9476  0.9478     0.026
# nb        0.9487  0.9469  0.9471     0.028
# lightgbm  0.9488  0.9469  0.9472     0.833
# et        0.9457  0.9442  0.9445     0.567
# gbc       0.9449  0.9428  0.9431     5.255
# qda       0.9421  0.9401  0.9404     0.028
# knn       0.9083  0.9060  0.9066     0.151
# lda       0.8632  0.8604  0.8613     0.026
# lr        0.8152  0.8120  0.8131     1.760
# ridge     0.1711  0.2371  0.2527     0.020
# svm       0.1949  0.2222  0.2684     0.140
# ada       0.1048  0.1345  0.2170     0.190
# dummy     0.0048  0.0000  0.0000     0.024

# %%
setup(data=df, target='label',feature_selection = True, feature_selection_method = 'boruta', feature_selection_threshold = 0.2, silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# rf               Random Forest Classifier    0.9955  1.0000  0.9952  0.9960
# nb                            Naive Bayes    0.9948  0.9999  0.9946  0.9956
# et                 Extra Trees Classifier    0.9942  0.9999  0.9938  0.9947
# qda       Quadratic Discriminant Analysis    0.9922  0.9999  0.9920  0.9927
# lightgbm  Light Gradient Boosting Machine    0.9883  1.0000  0.9884  0.9900
# gbc          Gradient Boosting Classifier    0.9857  1.0000  0.9852  0.9879
# dt               Decision Tree Classifier    0.9825  0.9908  0.9821  0.9857
# knn                K Neighbors Classifier    0.9786  0.9987  0.9782  0.9809
# lda          Linear Discriminant Analysis    0.9669  0.9997  0.9647  0.9724
# lr                    Logistic Regression    0.9643  0.9993  0.9631  0.9679
# ridge                    Ridge Classifier    0.7278  0.0000  0.7226  0.7068
# svm                   SVM - Linear Kernel    0.7186  0.0000  0.7196  0.7638
# ada                  Ada Boost Classifier    0.2216  0.7030  0.2182  0.1468
# dummy                    Dummy Classifier    0.0494  0.5000  0.0455  0.0024
#
#               F1   Kappa     MCC  TT (Sec)
# rf        0.9954  0.9952  0.9953     0.601
# nb        0.9947  0.9946  0.9946     0.030
# et        0.9941  0.9939  0.9939     0.536
# qda       0.9922  0.9918  0.9918     0.028
# lightgbm  0.9881  0.9877  0.9878     1.146
# gbc       0.9857  0.9850  0.9851     8.257
# dt        0.9821  0.9816  0.9818     0.029
# knn       0.9784  0.9775  0.9777     0.128
# lda       0.9664  0.9653  0.9656     0.027
# lr        0.9638  0.9625  0.9627     2.598
# ridge     0.6745  0.7146  0.7206     0.016
# svm       0.6999  0.7049  0.7227     0.083
# ada       0.1593  0.1818  0.2838     0.215
# dummy     0.0047  0.0000  0.0000     0.037

# %% [markdown]
# **Model performance using outlier removal**

# %%
setup(data=df, target='label',
      remove_outliers = True, outliers_threshold = 0.05, silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# nb                            Naive Bayes    0.9932  1.0000  0.9938  0.9940
# rf               Random Forest Classifier    0.9918  1.0000  0.9922  0.9931
# qda       Quadratic Discriminant Analysis    0.9904  0.9999  0.9908  0.9919
# et                 Extra Trees Classifier    0.9897  0.9999  0.9903  0.9909
# gbc          Gradient Boosting Classifier    0.9836  0.9999  0.9845  0.9864
# lightgbm  Light Gradient Boosting Machine    0.9836  0.9998  0.9838  0.9858
# dt               Decision Tree Classifier    0.9809  0.9899  0.9814  0.9839
# knn                K Neighbors Classifier    0.9740  0.9982  0.9748  0.9773
# lda          Linear Discriminant Analysis    0.9699  0.9997  0.9715  0.9759
# lr                    Logistic Regression    0.9596  0.9994  0.9625  0.9654
# svm                   SVM - Linear Kernel    0.7325  0.0000  0.7397  0.7714
# ridge                    Ridge Classifier    0.7168  0.0000  0.6952  0.7003
# ada                  Ada Boost Classifier    0.1703  0.7661  0.1692  0.0878
# dummy                    Dummy Classifier    0.0527  0.5000  0.0455  0.0028
#
#               F1   Kappa     MCC  TT (Sec)
# nb        0.9932  0.9928  0.9929     0.030
# rf        0.9917  0.9914  0.9915     0.581
# qda       0.9903  0.9900  0.9900     0.029
# et        0.9897  0.9892  0.9893     0.513
# gbc       0.9834  0.9828  0.9830     7.070
# lightgbm  0.9834  0.9828  0.9829     0.951
# dt        0.9804  0.9799  0.9801     0.027
# knn       0.9738  0.9727  0.9729     0.131
# lda       0.9694  0.9685  0.9688     0.027
# lr        0.9594  0.9577  0.9580     1.767
# svm       0.7063  0.7196  0.7310     0.094
# ridge     0.6641  0.7027  0.7092     0.015
# ada       0.1017  0.1271  0.1716     0.210
# dummy     0.0053  0.0000  0.0000     0.023

# %% [markdown]
# **Model Performance using pca**

# %%
setup(data=df, target='label',
      pca = True, pca_method = 'linear', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# qda       Quadratic Discriminant Analysis    0.9903  0.9999  0.9903  0.9914
# et                 Extra Trees Classifier    0.9870  0.9999  0.9867  0.9882
# nb                            Naive Bayes    0.9792  0.9998  0.9788  0.9819
# knn                K Neighbors Classifier    0.9785  0.9985  0.9778  0.9809
# lr                    Logistic Regression    0.9779  0.9998  0.9776  0.9800
# rf               Random Forest Classifier    0.9779  0.9997  0.9779  0.9800
# lightgbm  Light Gradient Boosting Machine    0.9740  0.9995  0.9737  0.9769
# gbc          Gradient Boosting Classifier    0.9545  0.9983  0.9545  0.9606
# lda          Linear Discriminant Analysis    0.9500  0.9993  0.9500  0.9577
# dt               Decision Tree Classifier    0.9480  0.9728  0.9470  0.9539
# svm                   SVM - Linear Kernel    0.8031  0.0000  0.8004  0.7919
# ridge                    Ridge Classifier    0.5906  0.0000  0.5748  0.4906
# ada                  Ada Boost Classifier    0.1670  0.7739  0.1648  0.1038
# dummy                    Dummy Classifier    0.0500  0.5000  0.0455  0.0025
#
#               F1   Kappa     MCC  TT (Sec)
# qda       0.9902  0.9898  0.9899     0.028
# et        0.9870  0.9864  0.9864     0.548
# nb        0.9791  0.9782  0.9783     0.028
# knn       0.9783  0.9775  0.9777     0.125
# lr        0.9778  0.9769  0.9770     2.513
# rf        0.9778  0.9768  0.9770     0.632
# lightgbm  0.9738  0.9728  0.9729     1.077
# gbc       0.9551  0.9523  0.9526     8.304
# lda       0.9495  0.9476  0.9480     0.043
# dt        0.9474  0.9455  0.9459     0.029
# svm       0.7746  0.7937  0.7984     0.075
# ridge     0.4906  0.5704  0.5821     0.015
# ada       0.0944  0.1247  0.1594     0.213
# dummy     0.0048  0.0000  0.0000     0.021

# %% [markdown]
# **Model performance using Transformation**

# %%
setup(data=df, target='label',
      transformation = True, transformation_method = 'yeo-johnson', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.9948  1.0000  0.9944  0.9956
# nb                            Naive Bayes    0.9942  0.9999  0.9937  0.9949
# rf               Random Forest Classifier    0.9942  1.0000  0.9939  0.9950
# qda       Quadratic Discriminant Analysis    0.9929  0.9999  0.9924  0.9939
# gbc          Gradient Boosting Classifier    0.9902  1.0000  0.9896  0.9914
# lightgbm  Light Gradient Boosting Machine    0.9889  0.9999  0.9885  0.9906
# dt               Decision Tree Classifier    0.9851  0.9922  0.9848  0.9869
# knn                K Neighbors Classifier    0.9747  0.9985  0.9752  0.9787
# lr                    Logistic Regression    0.9707  0.9994  0.9706  0.9738
# lda          Linear Discriminant Analysis    0.9668  0.9998  0.9669  0.9721
# svm                   SVM - Linear Kernel    0.9253  0.0000  0.9255  0.9483
# ridge                    Ridge Classifier    0.7245  0.0000  0.7186  0.6806
# ada                  Ada Boost Classifier    0.1871  0.7001  0.1818  0.0940
# dummy                    Dummy Classifier    0.0520  0.5000  0.0455  0.0027
#
#               F1   Kappa     MCC  TT (Sec)
# et        0.9948  0.9946  0.9946     0.513
# nb        0.9941  0.9939  0.9939     0.028
# rf        0.9941  0.9939  0.9939     0.702
# qda       0.9928  0.9925  0.9926     0.032
# gbc       0.9902  0.9898  0.9898     8.945
# lightgbm  0.9889  0.9884  0.9885     1.062
# dt        0.9850  0.9843  0.9844     0.032
# knn       0.9741  0.9734  0.9737     0.140
# lr        0.9704  0.9693  0.9695     0.189
# lda       0.9664  0.9653  0.9656     0.026
# svm       0.9268  0.9217  0.9230     0.093
# ridge     0.6630  0.7111  0.7177     0.030
# ada       0.1118  0.1440  0.2266     0.221
# dummy     0.0051  0.0000  0.0000     0.024

# %% [markdown]
# **Accuracy using "Outlier Removal" + "Normalization"**

# %%
setup(data=df, target='label',
      remove_outliers = True, outliers_threshold = 0.05,
      normalize = True, normalize_method = 'zscore', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# nb                            Naive Bayes    0.9925  1.0000  0.9931  0.9938
# rf               Random Forest Classifier    0.9925  1.0000  0.9930  0.9937
# qda       Quadratic Discriminant Analysis    0.9904  0.9999  0.9910  0.9918
# et                 Extra Trees Classifier    0.9904  0.9999  0.9910  0.9921
# lightgbm  Light Gradient Boosting Machine    0.9898  1.0000  0.9900  0.9912
# dt               Decision Tree Classifier    0.9856  0.9925  0.9866  0.9877
# gbc          Gradient Boosting Classifier    0.9829  0.9999  0.9837  0.9853
# knn                K Neighbors Classifier    0.9665  0.9966  0.9685  0.9716
# lr                    Logistic Regression    0.9617  0.9993  0.9640  0.9669
# lda          Linear Discriminant Analysis    0.9583  0.9996  0.9613  0.9649
# svm                   SVM - Linear Kernel    0.9077  0.0000  0.9101  0.9399
# ridge                    Ridge Classifier    0.6956  0.0000  0.6745  0.6634
# ada                  Ada Boost Classifier    0.1778  0.6707  0.1844  0.0951
# dummy                    Dummy Classifier    0.0540  0.5000  0.0455  0.0029
#
#               F1   Kappa     MCC  TT (Sec)
# nb        0.9924  0.9921  0.9922     0.045
# rf        0.9924  0.9921  0.9922     0.599
# qda       0.9903  0.9899  0.9900     0.028
# et        0.9903  0.9900  0.9901     0.515
# lightgbm  0.9897  0.9892  0.9893     1.032
# dt        0.9855  0.9849  0.9851     0.054
# gbc       0.9827  0.9821  0.9822     7.072
# knn       0.9657  0.9648  0.9651     0.134
# lr        0.9612  0.9598  0.9601     0.176
# lda       0.9577  0.9562  0.9566     0.039
# svm       0.9126  0.9031  0.9050     0.121
# ridge     0.6311  0.6803  0.6874     0.024
# ada       0.1090  0.1326  0.2252     0.219
# dummy     0.0055  0.0000  0.0000     0.022

# %% [markdown]
# **"Outlier Removal"+"Normalization"+"Transformation"**

# %%
setup(data=df, target='label',
      remove_outliers = True, outliers_threshold = 0.05, 
      normalize = True, normalize_method = 'zscore', 
      transformation = True, transformation_method = 'yeo-johnson', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# rf               Random Forest Classifier    0.9938  0.9999  0.9940  0.9950
# et                 Extra Trees Classifier    0.9938  0.9999  0.9939  0.9949
# nb                            Naive Bayes    0.9925  1.0000  0.9928  0.9936
# qda       Quadratic Discriminant Analysis    0.9911  0.9999  0.9917  0.9921
# lightgbm  Light Gradient Boosting Machine    0.9911  0.9999  0.9910  0.9924
# gbc          Gradient Boosting Classifier    0.9877  0.9999  0.9873  0.9888
# dt               Decision Tree Classifier    0.9863  0.9928  0.9865  0.9888
# lda          Linear Discriminant Analysis    0.9767  0.9997  0.9775  0.9791
# knn                K Neighbors Classifier    0.9740  0.9983  0.9728  0.9792
# lr                    Logistic Regression    0.9699  0.9996  0.9698  0.9735
# svm                   SVM - Linear Kernel    0.9302  0.0000  0.9317  0.9498
# ridge                    Ridge Classifier    0.7757  0.0000  0.7598  0.7260
# ada                  Ada Boost Classifier    0.1827  0.6554  0.1773  0.1136
# dummy                    Dummy Classifier    0.0499  0.5000  0.0455  0.0025
#
#               F1   Kappa     MCC  TT (Sec)
# rf        0.9937  0.9936  0.9936     0.582
# et        0.9937  0.9935  0.9936     0.519
# nb        0.9924  0.9921  0.9922     0.039
# qda       0.9910  0.9907  0.9907     0.029
# lightgbm  0.9910  0.9907  0.9908     1.032
# gbc       0.9876  0.9871  0.9871     7.148
# dt        0.9861  0.9857  0.9858     0.042
# lda       0.9765  0.9756  0.9758     0.026
# knn       0.9725  0.9727  0.9731     0.174
# lr        0.9692  0.9684  0.9687     0.301
# svm       0.9318  0.9268  0.9279     0.105
# ridge     0.7218  0.7646  0.7704     0.017
# ada       0.1236  0.1390  0.2451     0.216
# dummy     0.0048  0.0000  0.0000     0.021
